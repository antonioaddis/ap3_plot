# %%
import plot
import os

# %%
agilefile="~/projects/IGRJ17354-3255/2020/LS/AGILE/LSclean4/merged/RES1_TBS3600_R2_DQ1_EB100-10000.ap.ap4"
fermifile="~/projects/IGRJ17354-3255/2020/LS/FERMI/FER2_TBS300_R2_BARC0_EB100-10000.ap.ap4"
offpath="/Users/bulgarelli/projects/IGRJ17354-3255/2020/Table_3/"
#paper="/Users/bulgarelli/GoogleDriveINAF/Documents/Papers/2020_IGRJ17354-3255/5e5138f85dcd5b0001207a55/figures/"
paper="/Users/bulgarelli/tmpß/"

# %%
if 0:
    tstart=57753
    tstop=57754
    ofname=offpath+"dir_100_60.0_"+str(tstart)+".0_"+str(tstop)+".0"
    plot.main(agilefile, fermifile, tstart, tstop, ofname, [54732.166, 54732.333], plotrate=0)

# %%
plot.time_tt_to_mjd(410228700)
# Out:
# 57753.01736111111

# %%
#54732-54733
if 1:
    tstart=54732
    tstop=54733
    ofname=offpath+"dir_100_60.0_"+str(tstart)+".0_"+str(tstop)+".0"
    plot.main(agilefile, fermifile, tstart, tstop, ofname, [54732.166, 54732.333], plotrate=0)
    os.system("cp merged_plot_"+str(tstart)+"_"+str(tstop)+".pdf " + paper)
# Out:
# Green box in:  54732.0188813 54732.0342337
# Green box in:  54732.0890607 54732.1012361
# Green box in:  54732.5272493 54732.5410394
# Green box in:  54732.5950676 54732.612787
# Green box in:  54732.6630942 54732.6830879
# Green box in:  54732.7312945 54732.7527754
# Green box in:  54732.8008662 54732.8221041
# Green box in:  54732.8731001 54732.891317
# Green box in:  54732.9440549 54732.9604722
# Total time in GTI 16686.181445888244
# AGILE mean 1.9166666666666667
# AGILE median 1.0
# AGILE std 1.7173454405910418
# Fermi mean 2.282051282051282
# Fermi median 2.0
# Fermi std 2.2150455766026376
# Total time in GTI(bottom plot) 23400.0

# %%
#54746-54747
if 1:
    tstart=54746
    tstop=54747
    ofname=offpath+"dir_100_60.0_"+str(tstart)+".0_"+str(tstop)+".0"
    plot.main(agilefile, fermifile, tstart, tstop, ofname, [54746.0, 54746.166])
    os.system("cp merged_plot_"+str(tstart)+"_"+str(tstop)+".pdf " + paper)
# Out:
# Green box in:  54746.2538929 54746.2692915
# Green box in:  54746.3218963 54746.3403564
# Green box in:  54746.3899403 54746.4104837
# Green box in:  54746.4582274 54746.4800091
# Green box in:  54746.5291648 54746.5493147
# Green box in:  54746.6009415 54746.6185161
# Green box in:  54746.671607 54746.6876827
# Green box in:  54746.742041 54746.756155
# Green box in:  54746.8122609 54746.8197082
# Total time in GTI 16184.99231649004
# AGILE mean 1.5833333333333333
# AGILE median 1.0
# AGILE std 1.717345440591042
# Fermi mean 2.0123456790123457
# Fermi median 1.0
# Fermi std 2.3848156488526207
# Total time in GTI(bottom plot) 24300.0

# %%
#54915-54916
if 1:
    tstart=54915
    tstop=54916
    ofname=offpath+"dir_100_60.0_"+str(tstart)+".0_"+str(tstop)+".0"
    plot.main(agilefile, fermifile, tstart, tstop, ofname, [54915.0, 54915.125])
    os.system("cp merged_plot_"+str(tstart)+"_"+str(tstop)+".pdf " + paper)
# Out:
# Green box in:  54915.0299345 54915.0464209
# Green box in:  54915.1004148 54915.1154255
# Green box in:  54915.1705479 54915.1814441
# Green box in:  54915.6081174 54915.6229834
# Green box in:  54915.6760688 54915.6942681
# Green box in:  54915.7442227 54915.7644533
# Green box in:  54915.8123593 54915.8340482
# Green box in:  54915.8826313 54915.9033538
# Green box in:  54915.9546973 54915.9725552
# Total time in GTI 20066.65920162201
# AGILE mean 2.25
# AGILE median 2.5
# AGILE std 1.7257638510425513
# Fermi mean 2.6666666666666665
# Fermi median 1.0
# Fermi std 2.614064523559687
# Total time in GTI(bottom plot) 6300.0

# %%
#54935-54936
if 1:
    tstart=54935
    tstop=54936
    ofname=offpath+"dir_100_60.0_"+str(tstart)+".0_"+str(tstop)+".0"
    plot.main(agilefile, fermifile, tstart, tstop, ofname, [54935.25, 54935.50, 54935.666, 54935.833])
    os.system("cp merged_plot_"+str(tstart)+"_"+str(tstop)+".pdf " + paper)
# Out:
# Green box in:
    ofname=offpath+"dir_100_60.0_"+str(tstart)+".0_"+str(tstop)+".0"
    plot.main(agilefile, fermifile, tstart, tstop, ofname, [56182.0, 56182.25])
    os.system("cp merged_plot_"+str(tstart)+"_"+str(tstop)+".pdf " + paper)
# Out:
# Green box in:  56182.007805 56182.0123104
# Green box in:  56182.3757158 56182.3882826
# Green box in:  56182.4433662 56182.4606668
# Green box in:  56182.5113118 56182.5310256
# Green box in:  56182.5795005 56182.6007363
# Green box in:  56182.6481868 56182.6700303
# Green box in:  56182.7206116 56182.7391969
# Green box in:  56182.7915954 56182.8082826
# Green box in:  56182.8620236 56182.8772641
# Green box in:  56182.9321104 56182.9438034
# Total time in GTI 12965.667839330621
# AGILE mean 0.75
# AGILE median 1.0
# AGILE std 0.7372097807744856
# Fermi mean 1.9710144927536233
# Fermi median 1.0
# Fermi std 2.2555227285927852
# Total time in GTI(bottom plot) 20700.0

# %%
#56199-56200
if 1:
    tstart=56199
    tstop=56200
    ofname=offpath+"dir_100_60.0_"+str(tstart)+".0_"+str(tstop)+".0"
    plot.main(agilefile, fermifile, tstart, tstop, ofname, [56199.666, 56199.833])
    os.system("cp merged_plot_"+str(tstart)+"_"+str(tstop)+".pdf " + paper)
# Out:
# Green box in:  56199.0023535 56199.0119284
# Green box in:  56199.0695584 56199.0861645
# Green box in:  56199.1375388 56199.1567317
# Green box in:  56199.2056463 56199.2265928
# Green box in:  56199.2737829 56199.2959331
# Green box in:  56199.3458778 56199.3651113
# Green box in:  56199.4171626 56199.4342201
# Green box in:  56199.487643 56199.5033057
# Green box in:  56199.5577933 56199.570852
# Green box in:  56199.6280249 56199.6326113
# Total time in GTI 0
# AGILE mean 0.6666666666666666
# AGILE median 0.5
# AGILE std 0.7613869876268811
# Fermi mean nan
# Fermi median nan
# Fermi std nan
# Total time in GTI(bottom plot) 0.0

# %%
#56351-56352
if 1:
    tstart=56351
    tstop=56352
    ofname=offpath+"dir_100_60.0_"+str(tstart)+".0_"+str(tstop)+".0"
    plot.main(agilefile, fermifile, tstart, tstop, ofname, [56351.50, 56351.66])
    os.system("cp merged_plot_"+str(tstart)+"_"+str(tstop)+".pdf " + paper)
# Out:
# Green box in:  56351.0098362 56351.0320094
# Green box in:  56351.0819484 56351.1011761
# Green box in:  56351.1532158 56351.1702733
# Green box in:  56351.2236845 56351.2393358
# Green box in:  56351.2938176 56351.3068127
# Green box in:  56351.3640144 56351.3684793
# Green box in:  56351.7318095 56351.7443821
# Green box in:  56351.7994716 56351.8166969
# Green box in:  56351.8673709 56351.8870441
# Green box in:  56351.9355364 56351.9567432
# Total time in GTI 18577.19231902063
# AGILE mean 0.43478260869565216
# AGILE median 0.0
# AGILE std 0.6623708763718499
# Fermi mean 2.511111111111111
# Fermi median 2.0
# Fermi std 1.9496179371892592
# Total time in GTI(bottom plot) 13500.0

# %%
#57786-57787
if 1:
    tstart=57786
    tstop=57787
    ofname=offpath+"dir_100_60.0_"+str(tstart)+".0_"+str(tstop)+".0"
    plot.main(agilefile, fermifile, tstart, tstop, ofname, [57786.0, 57786.0])
    os.system("cp merged_plot_"+str(tstart)+"_"+str(tstop)+".pdf " + paper)
# Out:
# AGILE mean nan
# AGILE median nan
# AGILE std nan
# Fermi mean 4.32
# Fermi median 4.0
# Fermi std 3.0237945256470935
# Total time in GTI(bottom plot) 7500.0

# %%
#57823-57824
if 1:
    tstart=57823
    tstop=57824
    ofname=offpath+"dir_100_60.0_"+str(tstart)+".0_"+str(tstop)+".0"
    plot.main(agilefile, fermifile, tstart, tstop, ofname, [57823.0, 57823.0])
    os.system("cp merged_plot_"+str(tstart)+"_"+str(tstop)+".pdf " + paper)
# Out:
# AGILE mean 0.8333333333333334
# AGILE median 1.0
# AGILE std 0.7613869876268811
# Fermi mean 1.5789473684210527
# Fermi median 1.0
# Fermi std 1.8637822325921864
# Total time in GTI(bottom plot) 22800.0
